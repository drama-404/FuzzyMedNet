# %%
import numpy as np
import pandas as pd
import pickle

# %%
def load_from_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# %%
sample = load_from_pickle('../data/resampled/sample1.pkl')
sample
# Out:
# LEVEL2                                 anion gap            \
# Aggregation Function                        mask      mean
# subject_id hadm_id icustay_id hours_in
# 3          145834  211552     0              0.0  0.216667
#                               1              0.0  0.216667
#                               2              1.0  0.511111
#                               3              0.0  0.511111
#                               4              0.0  0.511111
#                               5              0.0  0.511111
#                               6              0.0  0.511111
#                               7              0.0  0.511111
#                               8              0.0  0.511111
#                               9              0.0  0.511111
#                               10             0.0  0.511111
#                               11             0.0  0.511111
#                               12             0.0  0.511111
# ...
